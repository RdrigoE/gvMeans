# %% [markdown]
# To run this script you must install python
# - https://www.python.org/downloads/
# Install pandas and openpyxl
# ```bash
# pip install pandas
# pip install jupiterlab
# pip install openpyxl
# ```

# %%
import pandas as pd

# %%
file_name = '~/Downloads/MembraneExperiments_CTR shScramble Exp1.xlsx'
sheet_name = 'C2Rednew_CTR (2)'
df = pd.read_excel(f'{file_name}', sheet_name, )

# %%
# Check data
df
# Out:
#          Distance  Groove 1 Gray Value   Unnamed: 2  Groove 2 Gray Value   \
# 0           0.000              1303.896         NaN               910.477
# 1           0.758              1555.345         NaN              1237.392
# 2           1.517              1668.885         NaN              1353.213
# 3           2.275              1778.740         NaN              1322.599
# 4           3.033              1594.692         NaN              1179.896
# ...           ...                   ...         ...                   ...
# 1048570       NaN                   NaN         NaN                   NaN
# 1048571       NaN                   NaN         NaN                   NaN
# 1048572       NaN                   NaN         NaN                   NaN
# 1048573       NaN                   NaN         NaN                   NaN
# 1048574       NaN                   NaN         NaN                   NaN
#
#          Unnamed: 4  Groove 3 Gray Value   Unnamed: 6  Groove 4 Gray Value   \
# 0               NaN              1096.969         NaN              7783.474
# 1               NaN              1253.414         NaN              7610.657
# 2               NaN              1292.263         NaN              7222.048
# 3               NaN              1150.672         NaN              6375.561
# 4               NaN               849.939         NaN              5838.195
# ...             ...                   ...         ...                   ...
# 1048570         NaN                   NaN         NaN                   NaN
# 1048571         NaN                   NaN         NaN                   NaN
# 1048572         NaN                   NaN         NaN                   NaN
# 1048573         NaN                   NaN         NaN                   NaN
# 1048574         NaN                   NaN         NaN                   NaN
#
#          Unnamed: 8  Groove 5 Gray Value   ...  Groove 12 Gray Value   \
# 0               NaN               555.980  ...                228.460
# 1               NaN               507.064  ...                226.288
# 2               NaN               485.587  ...                228.272
# 3               NaN               485.305  ...                236.992
# 4               NaN               457.409  ...                248.397
# ...             ...                   ...  ...                    ...
# 1048570         NaN                   NaN  ...                    NaN
# 1048571         NaN                   NaN  ...                    NaN
# 1048572         NaN                   NaN  ...                    NaN
# 1048573         NaN                   NaN  ...                    NaN
# 1048574         NaN                   NaN  ...                    NaN
#
#          Unnamed: 24  Groove 13 Gray Value   Unnamed: 26  \
# 0                NaN                769.502          NaN
# 1                NaN                800.615          NaN
# 2                NaN                793.347          NaN
# 3                NaN                789.491          NaN
# 4                NaN                797.267          NaN
# ...              ...                    ...          ...
# 1048570          NaN                    NaN          NaN
# 1048571          NaN                    NaN          NaN
# 1048572          NaN                    NaN          NaN
# 1048573          NaN                    NaN          NaN
# 1048574          NaN                    NaN          NaN
#
#          Groove 14 Gray Value   Unnamed: 28  Groove 15 Gray Value   \
# 0                      299.487          NaN                400.628
# 1                      356.853          NaN                434.430
# 2                      396.681          NaN                474.612
# 3                      418.132          NaN                478.647
# 4                      436.573          NaN                547.265
# ...                        ...          ...                    ...
# 1048570                    NaN          NaN                    NaN
# 1048571                    NaN          NaN                    NaN
# 1048572                    NaN          NaN                    NaN
# 1048573                    NaN          NaN                    NaN
# 1048574                    NaN          NaN                    NaN
#
#          Unnamed: 30  Groove 16 Gray Value   Unnamed: 32
# 0                NaN                646.837          NaN
# 1                NaN                717.866          NaN
# 2                NaN                735.915          NaN
# 3                NaN                726.370          NaN
# 4                NaN                709.423          NaN
# ...              ...                    ...          ...
# 1048570          NaN                    NaN          NaN
# 1048571          NaN                    NaN          NaN
# 1048572          NaN                    NaN          NaN
# 1048573          NaN                    NaN          NaN
# 1048574          NaN                    NaN          NaN
#
# [1048575 rows x 33 columns]

# %%
# Remove unnamed columns
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
# Remove rows filled with NaN (Not a number)
df = df.dropna(how='all')

# %%
# Calculate the mean using {window_size} values
window_size = 10


mean_df = pd.DataFrame();
for column in df:
    mean_df[column.replace('Value', 'Mean')] = [df[column][i:i + window_size].mean() for i in range(0, len(df), window_size)]

# %%
# Verify table with Means
mean_df
# Out:
#    Distance  Groove 1 Gray Mean   Groove 2 Gray Mean   Groove 3 Gray Mean   \
# 0    3.4125            1397.6701            1107.9525             875.5345
# 1   10.9955             943.2978             806.4574             525.4368
# 2   18.5788             982.7044             603.6180             595.3008
# 3   26.1619             808.7973             566.0556             544.0358
# 4   33.7452             784.2514             558.9075             605.4847
#
#    Groove 4 Gray Mean   Groove 5 Gray Mean   Groove 6 Gray Mean   \
# 0            6070.4656             492.0120             547.7438
# 1            4601.3195             463.1097             372.9944
# 2             912.1617             513.8637             392.6073
# 3             569.1896             477.3743             426.7166
# 4             520.7169             529.6932             429.3199
#
#    Groove 7 Gray Mean   Groove 8 Gray Mean   Groove 9 Gray Mean   \
# 0             346.9420             436.4566             714.7451
# 1             286.1114             335.9608             733.4171
# 2             304.7755             368.4480             760.4674
# 3             315.5501             288.7853             883.0250
# 4             333.2231             337.4403             881.9086
#
#    Groove 10 Gray Mean   Groove 11 Gray Mean   Groove 12 Gray Mean   \
# 0              888.4937             4745.9373              309.2396
# 1              847.8998             2997.9011              798.3068
# 2              706.5109              679.6844              569.7624
# 3              815.6350              703.2819              623.3364
# 4              785.7129              792.4565              703.7577
#
#    Groove 13 Gray Mean   Groove 14 Gray Mean   Groove 15 Gray Mean   \
# 0              841.0212              534.3182              557.1445
# 1             1177.9625              971.0950              940.2435
# 2             1041.0059              721.8899              773.6224
# 3             1018.6695              750.1329              823.5715
# 4              964.9697              738.3032              962.5190
#
#    Groove 16 Gray Mean
# 0              758.8289
# 1             1233.1880
# 2             1184.8853
# 3             1177.0756
# 4             1322.9564

# %%
file_means = f"{file_name[:-5]}__{sheet_name}__means.xlsx"
mean_df.to_excel(file_means)

# %%
columns = mean_df.columns[1:]
for idx, column in enumerate(columns[::-1]):
    index = len(columns) - idx
    # Calculate GV - min
    # For each Groove mean value do: Mean - Min(Groove X)
    gv_min = [mean_df[column][i] - min(mean_df[column]) for i in range(0, len(mean_df))]

    # Calculate %GV
    # For each Groove mean value do: (GV_min * 100) - Min(Groove X)
    p_min = [(gv_min[i] * 100) / max(mean_df[column]) for i in range(0, len(mean_df))]
    mean_df.insert(loc=index+1, column=f"GV-min {column}", value = gv_min)
    mean_df.insert(loc=index+2, column=f"%GV {column}", value = p_min)

# %%
mean_df
# Out:
#    Distance  Groove 1 Gray Mean   GV-min Groove 1 Gray Mean   \
# 0    3.4125            1397.6701                    613.4187
# 1   10.9955             943.2978                    159.0464
# 2   18.5788             982.7044                    198.4530
# 3   26.1619             808.7973                     24.5459
# 4   33.7452             784.2514                      0.0000
#
#    %GV Groove 1 Gray Mean   Groove 2 Gray Mean   GV-min Groove 2 Gray Mean   \
# 0                43.888662            1107.9525                    549.0450
# 1                11.379395             806.4574                    247.5499
# 2                14.198844             603.6180                     44.7105
# 3                 1.756201             566.0556                      7.1481
# 4                 0.000000             558.9075                      0.0000
#
#    %GV Groove 2 Gray Mean   Groove 3 Gray Mean   GV-min Groove 3 Gray Mean   \
# 0                49.554922             875.5345                    350.0977
# 1                22.343007             525.4368                      0.0000
# 2                 4.035417             595.3008                     69.8640
# 3                 0.645163             544.0358                     18.5990
# 4                 0.000000             605.4847                     80.0479
#
#    %GV Groove 3 Gray Mean   ...  %GV Groove 13 Gray Mean   \
# 0                39.986740  ...                  0.000000
# 1                 0.000000  ...                 28.603737
# 2                 7.979583  ...                 16.977170
# 3                 2.124302  ...                 15.080981
# 4                 9.142747  ...                 10.522279
#
#    Groove 14 Gray Mean   GV-min Groove 14 Gray Mean   \
# 0              534.3182                       0.0000
# 1              971.0950                     436.7768
# 2              721.8899                     187.5717
# 3              750.1329                     215.8147
# 4              738.3032                     203.9850
#
#    %GV Groove 14 Gray Mean   Groove 15 Gray Mean   \
# 0                  0.000000              557.1445
# 1                 44.977762              940.2435
# 2                 19.315484              773.6224
# 3                 22.223850              823.5715
# 4                 21.005669              962.5190
#
#    GV-min Groove 15 Gray Mean   %GV Groove 15 Gray Mean   \
# 0                       0.0000                  0.000000
# 1                     383.0990                 39.801708
# 2                     216.4779                 22.490766
# 3                     266.4270                 27.680181
# 4                     405.3745                 42.116000
#
#    Groove 16 Gray Mean   GV-min Groove 16 Gray Mean   %GV Groove 16 Gray Mean
# 0              758.8289                       0.0000                  0.000000
# 1             1233.1880                     474.3591                 35.855989
# 2             1184.8853                     426.0564                 32.204871
# 3             1177.0756                     418.2467                 31.614549
# 4             1322.9564                     564.1275                 42.641428
#
# [5 rows x 49 columns]

# %%
# Get only columns that start with '%GV'
mean_gv_df = mean_df.loc[:, mean_df.columns.str.contains(f'^%GV')]
mean_gv_df
# Out:
#    %GV Groove 1 Gray Mean   %GV Groove 2 Gray Mean   %GV Groove 3 Gray Mean   \
# 0                43.888662                49.554922                39.986740
# 1                11.379395                22.343007                 0.000000
# 2                14.198844                 4.035417                 7.979583
# 3                 1.756201                 0.645163                 2.124302
# 4                 0.000000                 0.000000                 9.142747
#
#    %GV Groove 4 Gray Mean   %GV Groove 5 Gray Mean   %GV Groove 6 Gray Mean   \
# 0                91.422126                 5.456423                31.903492
# 1                67.220587                 0.000000                 0.000000
# 2                 6.448349                 9.581773                 3.580670
# 3                 0.798501                 2.692993                 9.807907
# 4                 0.000000                12.570201                10.283183
#
#    %GV Groove 7 Gray Mean   %GV Groove 8 Gray Mean   %GV Groove 9 Gray Mean   \
# 0                17.533363                33.834132                 0.000000
# 1                 0.000000                10.808749                 2.114549
# 2                 5.379602                18.252147                 5.177917
# 3                 8.485193                 0.000000                19.057207
# 4                13.579128                11.147729                18.930778
#
#    %GV Groove 10 Gray Mean   %GV Groove 11 Gray Mean   \
# 0                 20.482171                 85.678606
# 1                 15.913326                 48.846341
# 2                  0.000000                  0.000000
# 3                 12.281922                  0.497215
# 4                  8.914188                  2.376182
#
#    %GV Groove 12 Gray Mean   %GV Groove 13 Gray Mean   \
# 0                  0.000000                  0.000000
# 1                 61.263063                 28.603737
# 2                 32.634421                 16.977170
# 3                 39.345374                 15.080981
# 4                 49.419359                 10.522279
#
#    %GV Groove 14 Gray Mean   %GV Groove 15 Gray Mean   \
# 0                  0.000000                  0.000000
# 1                 44.977762                 39.801708
# 2                 19.315484                 22.490766
# 3                 22.223850                 27.680181
# 4                 21.005669                 42.116000
#
#    %GV Groove 16 Gray Mean
# 0                  0.000000
# 1                 35.855989
# 2                 32.204871
# 3                 31.614549
# 4                 42.641428

# %%
# Calculate mean for each row
mean_gv = [i[1].mean() for i in mean_gv_df.iterrows()]
mean_gv_df.insert(loc=len(mean_gv_df.columns),column=f'MeanGV %GV',value=mean_gv)

# %%
# Final table
mean_gv_df
# Out:
#    %GV Groove 1 Gray Mean   %GV Groove 2 Gray Mean   %GV Groove 3 Gray Mean   \
# 0                43.888662                49.554922                39.986740
# 1                11.379395                22.343007                 0.000000
# 2                14.198844                 4.035417                 7.979583
# 3                 1.756201                 0.645163                 2.124302
# 4                 0.000000                 0.000000                 9.142747
#
#    %GV Groove 4 Gray Mean   %GV Groove 5 Gray Mean   %GV Groove 6 Gray Mean   \
# 0                91.422126                 5.456423                31.903492
# 1                67.220587                 0.000000                 0.000000
# 2                 6.448349                 9.581773                 3.580670
# 3                 0.798501                 2.692993                 9.807907
# 4                 0.000000                12.570201                10.283183
#
#    %GV Groove 7 Gray Mean   %GV Groove 8 Gray Mean   %GV Groove 9 Gray Mean   \
# 0                17.533363                33.834132                 0.000000
# 1                 0.000000                10.808749                 2.114549
# 2                 5.379602                18.252147                 5.177917
# 3                 8.485193                 0.000000                19.057207
# 4                13.579128                11.147729                18.930778
#
#    %GV Groove 10 Gray Mean   %GV Groove 11 Gray Mean   \
# 0                 20.482171                 85.678606
# 1                 15.913326                 48.846341
# 2                  0.000000                  0.000000
# 3                 12.281922                  0.497215
# 4                  8.914188                  2.376182
#
#    %GV Groove 12 Gray Mean   %GV Groove 13 Gray Mean   \
# 0                  0.000000                  0.000000
# 1                 61.263063                 28.603737
# 2                 32.634421                 16.977170
# 3                 39.345374                 15.080981
# 4                 49.419359                 10.522279
#
#    %GV Groove 14 Gray Mean   %GV Groove 15 Gray Mean   \
# 0                  0.000000                  0.000000
# 1                 44.977762                 39.801708
# 2                 19.315484                 22.490766
# 3                 22.223850                 27.680181
# 4                 21.005669                 42.116000
#
#    %GV Groove 16 Gray Mean   MeanGV %GV
# 0                  0.000000   26.233790
# 1                 35.855989   24.320513
# 2                 32.204871   12.391063
# 3                 31.614549   12.130721
# 4                 42.641428   15.790554

# %%
file_p_gv_means = f"{file_name[:-5]}__{sheet_name}__final.xlsx"
mean_gv_df.to_excel(file_p_gv_means)
