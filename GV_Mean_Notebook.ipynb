# %% [markdown]
# To run this script you must install python
# - https://www.python.org/downloads/
# Install pandas and openpyxl
# ```bash
# pip install pandas
# pip install jupiterlab
# pip install openpyxl
# ```

# %%
import pandas as pd

# %%
filename = '~/Downloads/MembraneExperiments_CTR shScramble Exp1.xlsx'
sheet_name = 'C2Rednew_CTR (2)'
df = pd.read_excel(f'{filename}', sheet_name, )

# %%
# Check data
df
# Out:
#          Distance  Groove 1 Gray Value   Unnamed: 2  Groove 2 Gray Value   \
# 0           0.000              1303.896         NaN               910.477
# 1           0.758              1555.345         NaN              1237.392
# 2           1.517              1668.885         NaN              1353.213
# 3           2.275              1778.740         NaN              1322.599
# 4           3.033              1594.692         NaN              1179.896
# ...           ...                   ...         ...                   ...
# 1048570       NaN                   NaN         NaN                   NaN
# 1048571       NaN                   NaN         NaN                   NaN
# 1048572       NaN                   NaN         NaN                   NaN
# 1048573       NaN                   NaN         NaN                   NaN
# 1048574       NaN                   NaN         NaN                   NaN
#
#          Unnamed: 4  Groove 3 Gray Value   Unnamed: 6  Groove 4 Gray Value   \
# 0               NaN              1096.969         NaN              7783.474
# 1               NaN              1253.414         NaN              7610.657
# 2               NaN              1292.263         NaN              7222.048
# 3               NaN              1150.672         NaN              6375.561
# 4               NaN               849.939         NaN              5838.195
# ...             ...                   ...         ...                   ...
# 1048570         NaN                   NaN         NaN                   NaN
# 1048571         NaN                   NaN         NaN                   NaN
# 1048572         NaN                   NaN         NaN                   NaN
# 1048573         NaN                   NaN         NaN                   NaN
# 1048574         NaN                   NaN         NaN                   NaN
#
#          Unnamed: 8  Groove 5 Gray Value   ...  Groove 12 Gray Value   \
# 0               NaN               555.980  ...                228.460
# 1               NaN               507.064  ...                226.288
# 2               NaN               485.587  ...                228.272
# 3               NaN               485.305  ...                236.992
# 4               NaN               457.409  ...                248.397
# ...             ...                   ...  ...                    ...
# 1048570         NaN                   NaN  ...                    NaN
# 1048571         NaN                   NaN  ...                    NaN
# 1048572         NaN                   NaN  ...                    NaN
# 1048573         NaN                   NaN  ...                    NaN
# 1048574         NaN                   NaN  ...                    NaN
#
#          Unnamed: 24  Groove 13 Gray Value   Unnamed: 26  \
# 0                NaN                769.502          NaN
# 1                NaN                800.615          NaN
# 2                NaN                793.347          NaN
# 3                NaN                789.491          NaN
# 4                NaN                797.267          NaN
# ...              ...                    ...          ...
# 1048570          NaN                    NaN          NaN
# 1048571          NaN                    NaN          NaN
# 1048572          NaN                    NaN          NaN
# 1048573          NaN                    NaN          NaN
# 1048574          NaN                    NaN          NaN
#
#          Groove 14 Gray Value   Unnamed: 28  Groove 15 Gray Value   \
# 0                      299.487          NaN                400.628
# 1                      356.853          NaN                434.430
# 2                      396.681          NaN                474.612
# 3                      418.132          NaN                478.647
# 4                      436.573          NaN                547.265
# ...                        ...          ...                    ...
# 1048570                    NaN          NaN                    NaN
# 1048571                    NaN          NaN                    NaN
# 1048572                    NaN          NaN                    NaN
# 1048573                    NaN          NaN                    NaN
# 1048574                    NaN          NaN                    NaN
#
#          Unnamed: 30  Groove 16 Gray Value   Unnamed: 32
# 0                NaN                646.837          NaN
# 1                NaN                717.866          NaN
# 2                NaN                735.915          NaN
# 3                NaN                726.370          NaN
# 4                NaN                709.423          NaN
# ...              ...                    ...          ...
# 1048570          NaN                    NaN          NaN
# 1048571          NaN                    NaN          NaN
# 1048572          NaN                    NaN          NaN
# 1048573          NaN                    NaN          NaN
# 1048574          NaN                    NaN          NaN
#
# [1048575 rows x 33 columns]

# %%
# Remove unnamed columns
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
# Remove rows filled with NaN (Not a number)
df = df.dropna(how='all')

# %%
# Calculate the mean using {window_size} values
window_size = 10


mean_df = pd.DataFrame();
for column in df:
    mean_df[column.replace('Value', 'Mean')] = [df[column][i:i + window_size].mean() for i in range(0, len(df), window_size)]

# %%
# Verify table with Means
mean_df
# Out:
#     Distance  Groove 1 Gray Mean   Groove 2 Gray Mean   Groove 3 Gray Mean   \
# 0     3.4125            1397.6701          1107.952500           875.534500
# 1    10.9955             943.2978           806.457400           525.436800
# 2    18.5788             982.7044           603.618000           595.300800
# 3    26.1619             808.7973           566.055600           544.035800
# 4    33.7452             784.2514           558.907500           605.484700
# ..       ...                  ...                  ...                  ...
# 92  701.0645             539.9928           495.408500           607.105300
# 93  708.6476             609.1986           603.765300           634.550900
# 94  716.2308             733.7398           586.128571           764.955429
# 95  721.9184            1931.0944                  NaN                  NaN
# 96       NaN                  NaN                  NaN                  NaN
#
#     Groove 4 Gray Mean   Groove 5 Gray Mean   Groove 6 Gray Mean   \
# 0             6070.4656           492.012000           547.743800
# 1             4601.3195           463.109700           372.994400
# 2              912.1617           513.863700           392.607300
# 3              569.1896           477.374300           426.716600
# 4              520.7169           529.693200           429.319900
# ..                  ...                  ...                  ...
# 92            1200.2840          1328.610500          1080.434200
# 93            1177.2555          1648.308800          1328.727800
# 94             112.2780          1903.508167          1586.937833
# 95                  NaN                  NaN                  NaN
# 96                  NaN                  NaN                  NaN
#
#     Groove 7 Gray Mean   Groove 8 Gray Mean   Groove 9 Gray Mean   \
# 0              346.9420           436.456600           714.745100
# 1              286.1114           335.960800           733.417100
# 2              304.7755           368.448000           760.467400
# 3              315.5501           288.785300           883.025000
# 4              333.2231           337.440300           881.908600
# ..                  ...                  ...                  ...
# 92             759.6388          1010.604500          1593.643900
# 93            1132.0980          1429.822000          1589.910700
# 94            1181.4535          1344.531167          1745.335600
# 95                  NaN                  NaN          2283.939111
# 96                  NaN                  NaN                  NaN
#
#     Groove 10 Gray Mean   Groove 11 Gray Mean   Groove 12 Gray Mean   \
# 0             888.493700             4745.9373            309.239600
# 1             847.899800             2997.9011            798.306800
# 2             706.510900              679.6844            569.762400
# 3             815.635000              703.2819            623.336400
# 4             785.712900              792.4565            703.757700
# ..                   ...                   ...                   ...
# 92           1593.463200             2252.9758           3364.558700
# 93           1786.765400             2222.8727           3500.446900
# 94           2210.720700             1889.0950           3772.654300
# 95           2619.991222                0.0000           1568.749667
# 96                   NaN                   NaN                   NaN
#
#     Groove 13 Gray Mean   Groove 14 Gray Mean   Groove 15 Gray Mean   \
# 0               841.0212              534.3182              557.1445
# 1              1177.9625              971.0950              940.2435
# 2              1041.0059              721.8899              773.6224
# 3              1018.6695              750.1329              823.5715
# 4               964.9697              738.3032              962.5190
# ..                   ...                   ...                   ...
# 92             2588.2494             2629.8923             2237.8825
# 93             2767.8030             2675.0077             2091.1183
# 94             2789.1339             2596.6828             2776.1021
# 95             3665.0635             2924.5173             2061.1088
# 96             4521.0830             3164.5700                0.0000
#
#     Groove 16 Gray Mean
# 0               758.8289
# 1              1233.1880
# 2              1184.8853
# 3              1177.0756
# 4              1322.9564
# ..                   ...
# 92             3883.1895
# 93             4006.9424
# 94             4024.2526
# 95             1067.6098
# 96                0.0000
#
# [97 rows x 17 columns]

# %%
mean_df.to_excel(filename + '__means' + '.xlsx')

# %%
columns = mean_df.columns[1:]
for idx, column in enumerate(columns[::-1]):
    index = len(columns) - idx
    # Calculate GV - min
    # For each Groove mean value do: Mean - Min(Groove X)
    gv_min = [mean_df[column][i] - min(mean_df[column]) for i in range(0, len(mean_df))]

    # Calculate %GV
    # For each Groove mean value do: (GV_min * 100) - Min(Groove X)
    p_min = [(gv_min[i] * 100) - min(mean_df[column]) / max(mean_df[column]) for i in range(0, len(mean_df))]
    mean_df.insert(loc=index+1, column=f"GV-min {column}", value = gv_min)
    mean_df.insert(loc=index+2, column=f"%GV {column}", value = p_min)

# %%
mean_df
# Out:
#     Distance  Groove 1 Gray Mean   GV-min Groove 1 Gray Mean   \
# 0     3.4125            1397.6701                   1048.2971
# 1    10.9955             943.2978                    593.9248
# 2    18.5788             982.7044                    633.3314
# 3    26.1619             808.7973                    459.4243
# 4    33.7452             784.2514                    434.8784
# ..       ...                  ...                         ...
# 92  701.0645             539.9928                    190.6198
# 93  708.6476             609.1986                    259.8256
# 94  716.2308             733.7398                    384.3668
# 95  721.9184            1931.0944                   1581.7214
# 96       NaN                  NaN                         NaN
#
#     %GV Groove 1 Gray Mean   Groove 2 Gray Mean   GV-min Groove 2 Gray Mean   \
# 0              104829.52908          1107.952500                  736.157200
# 1               59392.29908           806.457400                  434.662100
# 2               63332.95908           603.618000                  231.822700
# 3               45942.24908           566.055600                  194.260300
# 4               43487.65908           558.907500                  187.112200
# ..                      ...                  ...                         ...
# 92              19061.79908           495.408500                  123.613200
# 93              25982.37908           603.765300                  231.970000
# 94              38436.49908           586.128571                  214.333271
# 95             158171.95908                  NaN                         NaN
# 96                      NaN                  NaN                         NaN
#
#     %GV Groove 2 Gray Mean   Groove 3 Gray Mean   GV-min Groove 3 Gray Mean   \
# 0              73615.384430           875.534500                  528.603100
# 1              43465.874430           525.436800                  178.505400
# 2              23181.934430           595.300800                  248.369400
# 3              19425.694430           544.035800                  197.104400
# 4              18710.884430           605.484700                  258.553300
# ..                      ...                  ...                         ...
# 92             12360.984430           607.105300                  260.173900
# 93             23196.664430           634.550900                  287.619500
# 94             21432.991573           764.955429                  418.024029
# 95                      NaN                  NaN                         NaN
# 96                      NaN                  NaN                         NaN
#
#     %GV Groove 3 Gray Mean   ...  %GV Groove 13 Gray Mean   \
# 0              52859.913749  ...                 -0.186022
# 1              17850.143749  ...              33693.943978
# 2              24836.543749  ...              19998.283978
# 3              19710.043749  ...              17764.643978
# 4              25854.933749  ...              12394.663978
# ..                      ...  ...                       ...
# 92             26016.993749  ...             174722.633978
# 93             28761.553749  ...             192677.993978
# 94             41802.006606  ...             194811.083978
# 95                      NaN  ...             282404.043978
# 96                      NaN  ...             368005.993978
#
#     Groove 14 Gray Mean   GV-min Groove 14 Gray Mean   \
# 0               534.3182                       0.0000
# 1               971.0950                     436.7768
# 2               721.8899                     187.5717
# 3               750.1329                     215.8147
# 4               738.3032                     203.9850
# ..                   ...                          ...
# 92             2629.8923                    2095.5741
# 93             2675.0077                    2140.6895
# 94             2596.6828                    2062.3646
# 95             2924.5173                    2390.1991
# 96             3164.5700                    2630.2518
#
#     %GV Groove 14 Gray Mean   Groove 15 Gray Mean   \
# 0                  -0.168844              557.1445
# 1               43677.511156              940.2435
# 2               18757.001156              773.6224
# 3               21581.301156              823.5715
# 4               20398.331156              962.5190
# ..                       ...                   ...
# 92             209557.241156             2237.8825
# 93             214068.781156             2091.1183
# 94             206236.291156             2776.1021
# 95             239019.741156             2061.1088
# 96             263025.011156                0.0000
#
#     GV-min Groove 15 Gray Mean   %GV Groove 15 Gray Mean   \
# 0                      557.1445                  55714.45
# 1                      940.2435                  94024.35
# 2                      773.6224                  77362.24
# 3                      823.5715                  82357.15
# 4                      962.5190                  96251.90
# ..                          ...                       ...
# 92                    2237.8825                 223788.25
# 93                    2091.1183                 209111.83
# 94                    2776.1021                 277610.21
# 95                    2061.1088                 206110.88
# 96                       0.0000                      0.00
#
#     Groove 16 Gray Mean   GV-min Groove 16 Gray Mean   \
# 0               758.8289                     758.8289
# 1              1233.1880                    1233.1880
# 2              1184.8853                    1184.8853
# 3              1177.0756                    1177.0756
# 4              1322.9564                    1322.9564
# ..                   ...                          ...
# 92             3883.1895                    3883.1895
# 93             4006.9424                    4006.9424
# 94             4024.2526                    4024.2526
# 95             1067.6098                    1067.6098
# 96                0.0000                       0.0000
#
#     %GV Groove 16 Gray Mean
# 0                   75882.89
# 1                  123318.80
# 2                  118488.53
# 3                  117707.56
# 4                  132295.64
# ..                       ...
# 92                 388318.95
# 93                 400694.24
# 94                 402425.26
# 95                 106760.98
# 96                      0.00
#
# [97 rows x 49 columns]

# %%
# Get only columns that start with '%GV'
mean_gv_df = mean_df.loc[:, mean_df.columns.str.contains(f'^%GV')]
mean_gv_df
# Out:
#     %GV Groove 1 Gray Mean   %GV Groove 2 Gray Mean   %GV Groove 3 Gray Mean   \
# 0              104829.52908             73615.384430             52859.913749
# 1               59392.29908             43465.874430             17850.143749
# 2               63332.95908             23181.934430             24836.543749
# 3               45942.24908             19425.694430             19710.043749
# 4               43487.65908             18710.884430             25854.933749
# ..                      ...                      ...                      ...
# 92              19061.79908             12360.984430             26016.993749
# 93              25982.37908             23196.664430             28761.553749
# 94              38436.49908             21432.991573             41802.006606
# 95             158171.95908                      NaN                      NaN
# 96                      NaN                      NaN                      NaN
#
#     %GV Groove 4 Gray Mean   %GV Groove 5 Gray Mean   %GV Groove 6 Gray Mean   \
# 0             595818.741504              2889.986707             17474.704960
# 1             448904.131504                -0.243293                -0.235040
# 2              79988.351504              5075.156707              1961.054960
# 3              45691.141504              1426.216707              5371.984960
# 4              40843.871504              6658.106707              5632.314960
# ..                      ...                      ...                      ...
# 92            108800.581504             86549.836707             70743.744960
# 93            106497.731504            118519.666707             95573.104960
# 94                -0.018496            144039.603374            121394.108293
# 95                      NaN                      NaN                      NaN
# 96                      NaN                      NaN                      NaN
#
#     %GV Groove 7 Gray Mean   %GV Groove 8 Gray Mean   %GV Groove 9 Gray Mean   \
# 0               6082.817831             14766.928027                -0.312944
# 1                 -0.242169              4717.348027              1866.887056
# 2               1866.167831              7966.068027              4571.917056
# 3               2943.627831                -0.201973             16827.677056
# 4               4710.927831              4865.298027             16716.037056
# ..                      ...                      ...                      ...
# 92             47352.497831             72181.718027             87889.567056
# 93             84598.417831            114103.468027             87516.247056
# 94             89533.967831            105574.384694            103058.737056
# 95                      NaN                      NaN            156919.088167
# 96                      NaN                      NaN                      NaN
#
#     %GV Groove 10 Gray Mean   %GV Groove 11 Gray Mean   \
# 0               18198.010338                 474593.73
# 1               14138.620338                 299790.11
# 2                  -0.269662                  67968.44
# 3               10912.140338                  70328.19
# 4                7919.930338                  79245.65
# ..                       ...                       ...
# 92              88694.960338                 225297.58
# 93             108025.180338                 222287.27
# 94             150420.710338                 188909.50
# 95             191347.762561                      0.00
# 96                       NaN                       NaN
#
#     %GV Groove 12 Gray Mean   %GV Groove 13 Gray Mean   \
# 0                  -0.081969                 -0.186022
# 1               48906.638031              33693.943978
# 2               26052.198031              19998.283978
# 3               31409.598031              17764.643978
# 4               39451.728031              12394.663978
# ..                       ...                       ...
# 92             305531.828031             174722.633978
# 93             319120.648031             192677.993978
# 94             346341.388031             194811.083978
# 95             125950.924698             282404.043978
# 96                       NaN             368005.993978
#
#     %GV Groove 14 Gray Mean   %GV Groove 15 Gray Mean   \
# 0                  -0.168844                  55714.45
# 1               43677.511156                  94024.35
# 2               18757.001156                  77362.24
# 3               21581.301156                  82357.15
# 4               20398.331156                  96251.90
# ..                       ...                       ...
# 92             209557.241156                 223788.25
# 93             214068.781156                 209111.83
# 94             206236.291156                 277610.21
# 95             239019.741156                 206110.88
# 96             263025.011156                      0.00
#
#     %GV Groove 16 Gray Mean
# 0                   75882.89
# 1                  123318.80
# 2                  118488.53
# 3                  117707.56
# 4                  132295.64
# ..                       ...
# 92                 388318.95
# 93                 400694.24
# 94                 402425.26
# 95                 106760.98
# 96                      0.00
#
# [97 rows x 16 columns]

# %%
# Calculate mean for each row
mean_gv = [i[1].mean() for i in mean_gv_df.iterrows()]
mean_gv_df.insert(loc=len(mean_gv_df.columns),column=f'MeanGV %GV',value=mean_gv)

# %%
# Final table
mean_gv_df
# Out:
#     %GV Groove 1 Gray Mean   %GV Groove 2 Gray Mean   %GV Groove 3 Gray Mean   \
# 0              104829.52908             73615.384430             52859.913749
# 1               59392.29908             43465.874430             17850.143749
# 2               63332.95908             23181.934430             24836.543749
# 3               45942.24908             19425.694430             19710.043749
# 4               43487.65908             18710.884430             25854.933749
# ..                      ...                      ...                      ...
# 92              19061.79908             12360.984430             26016.993749
# 93              25982.37908             23196.664430             28761.553749
# 94              38436.49908             21432.991573             41802.006606
# 95             158171.95908                      NaN                      NaN
# 96                      NaN                      NaN                      NaN
#
#     %GV Groove 4 Gray Mean   %GV Groove 5 Gray Mean   %GV Groove 6 Gray Mean   \
# 0             595818.741504              2889.986707             17474.704960
# 1             448904.131504                -0.243293                -0.235040
# 2              79988.351504              5075.156707              1961.054960
# 3              45691.141504              1426.216707              5371.984960
# 4              40843.871504              6658.106707              5632.314960
# ..                      ...                      ...                      ...
# 92            108800.581504             86549.836707             70743.744960
# 93            106497.731504            118519.666707             95573.104960
# 94                -0.018496            144039.603374            121394.108293
# 95                      NaN                      NaN                      NaN
# 96                      NaN                      NaN                      NaN
#
#     %GV Groove 7 Gray Mean   %GV Groove 8 Gray Mean   %GV Groove 9 Gray Mean   \
# 0               6082.817831             14766.928027                -0.312944
# 1                 -0.242169              4717.348027              1866.887056
# 2               1866.167831              7966.068027              4571.917056
# 3               2943.627831                -0.201973             16827.677056
# 4               4710.927831              4865.298027             16716.037056
# ..                      ...                      ...                      ...
# 92             47352.497831             72181.718027             87889.567056
# 93             84598.417831            114103.468027             87516.247056
# 94             89533.967831            105574.384694            103058.737056
# 95                      NaN                      NaN            156919.088167
# 96                      NaN                      NaN                      NaN
#
#     %GV Groove 10 Gray Mean   %GV Groove 11 Gray Mean   \
# 0               18198.010338                 474593.73
# 1               14138.620338                 299790.11
# 2                  -0.269662                  67968.44
# 3               10912.140338                  70328.19
# 4                7919.930338                  79245.65
# ..                       ...                       ...
# 92              88694.960338                 225297.58
# 93             108025.180338                 222287.27
# 94             150420.710338                 188909.50
# 95             191347.762561                      0.00
# 96                       NaN                       NaN
#
#     %GV Groove 12 Gray Mean   %GV Groove 13 Gray Mean   \
# 0                  -0.081969                 -0.186022
# 1               48906.638031              33693.943978
# 2               26052.198031              19998.283978
# 3               31409.598031              17764.643978
# 4               39451.728031              12394.663978
# ..                       ...                       ...
# 92             305531.828031             174722.633978
# 93             319120.648031             192677.993978
# 94             346341.388031             194811.083978
# 95             125950.924698             282404.043978
# 96                       NaN             368005.993978
#
#     %GV Groove 14 Gray Mean   %GV Groove 15 Gray Mean   \
# 0                  -0.168844                  55714.45
# 1               43677.511156                  94024.35
# 2               18757.001156                  77362.24
# 3               21581.301156                  82357.15
# 4               20398.331156                  96251.90
# ..                       ...                       ...
# 92             209557.241156                 223788.25
# 93             214068.781156                 209111.83
# 94             206236.291156                 277610.21
# 95             239019.741156                 206110.88
# 96             263025.011156                      0.00
#
#     %GV Groove 16 Gray Mean      MeanGV %GV
# 0                   75882.89   93295.396053
# 1                  123318.80   77109.121053
# 2                  118488.53   33837.911053
# 3                  117707.56   31837.438553
# 4                  132295.64   34714.867303
# ..                       ...            ...
# 92                 388318.95  134179.322928
# 93                 400694.24  146920.948553
# 94                 402425.26  152001.670220
# 95                 106760.98  162965.042182
# 96                      0.00  157757.751284
#
# [97 rows x 17 columns]

# %%
mean_gv_df.to_excel(filename + '__final' + '.xlsx')
